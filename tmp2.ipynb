# %%
import warnings
warnings.filterwarnings("ignore")
from src.services.embedding_visualizer_service import EmbeddingVisualizer

vis = EmbeddingVisualizer('./data/Natural-Questions-LLM-responses-400.csv', './data/results/padding_2d')
vis.load_data()
vis.process_embeddings_padding()
vis.apply_umap(n_components=2)
vis.plot_umap_2d()
# Out:
# 2024-10-12 19:25:46,875 - INFO - Data loaded with shape (391, 12)
# 2024-10-12 19:25:46,875 - INFO - Columns: Index(['uid', 'question', 'true_answer', 'phi3', 'llama3.1', 'gemma2',
#        'embedding_phi3', 'embedding_llama3.1', 'embedding_gemma2',
#        'true_answer_embedding_phi3', 'true_answer_embedding_llama3.1',
#        'true_answer_embedding_gemma2'],
#       dtype='object')
# 2024-10-12 19:25:47,438 - INFO - Combined dataset created with shape (1173, 4097)
# 2024-10-12 19:25:47,444 - INFO - Label names set to {0: 'Llama3', 1: 'Gemma2', 2: 'Phi3'}
# 2024-10-12 19:25:47,444 - INFO - Padding applied. Reduced embeddings shape: (1173, 4096)
# 2024-10-12 19:25:53,257 - INFO - UMAP applied in 2D, resulting in shape (1173, 2)
# 2024-10-12 19:25:53,491 - INFO - 2D UMAP plot saved at ./data/results/padding_2d

# %%
from src.services.embedding_visualizer_service import EmbeddingVisualizer

vis = EmbeddingVisualizer('./data/Natural-Questions-LLM-responses-400.csv', './data/results/padding_3d')
vis.load_data()
vis.process_embeddings_padding()
vis.apply_umap(n_components=3)
vis.plot_umap_3d()
# Out:
# 2024-10-12 19:26:08,172 - INFO - Data loaded with shape (391, 12)
# 2024-10-12 19:26:08,173 - INFO - Columns: Index(['uid', 'question', 'true_answer', 'phi3', 'llama3.1', 'gemma2',
#        'embedding_phi3', 'embedding_llama3.1', 'embedding_gemma2',
#        'true_answer_embedding_phi3', 'true_answer_embedding_llama3.1',
#        'true_answer_embedding_gemma2'],
#       dtype='object')
# 2024-10-12 19:26:08,745 - INFO - Combined dataset created with shape (1173, 4097)
# 2024-10-12 19:26:08,753 - INFO - Label names set to {0: 'Llama3', 1: 'Gemma2', 2: 'Phi3'}
# 2024-10-12 19:26:08,754 - INFO - Padding applied. Reduced embeddings shape: (1173, 4096)
# 2024-10-12 19:26:12,571 - INFO - UMAP applied in 3D, resulting in shape (1173, 3)
# 2024-10-12 19:26:12,709 - INFO - 3D UMAP plot saved at ./data/results/padding_3d

# %%
from src.services.embedding_visualizer_service import EmbeddingVisualizer

vis = EmbeddingVisualizer('./data/Natural-Questions-LLM-responses-400.csv', './data/results/pca_2d')
vis.load_data()
vis.process_embeddings_PCA(target_dim=150)
vis.apply_umap(n_components=2)
vis.plot_umap_2d()
# Out:
# 2024-10-12 19:26:19,816 - INFO - Data loaded with shape (391, 12)
# 2024-10-12 19:26:19,816 - INFO - Columns: Index(['uid', 'question', 'true_answer', 'phi3', 'llama3.1', 'gemma2',
#        'embedding_phi3', 'embedding_llama3.1', 'embedding_gemma2',
#        'true_answer_embedding_phi3', 'true_answer_embedding_llama3.1',
#        'true_answer_embedding_gemma2'],
#       dtype='object')
# 2024-10-12 19:26:30,955 - INFO - Label names set to {0: 'Llama3', 1: 'Gemma2', 2: 'Phi3'}
# 2024-10-12 19:26:30,958 - INFO - PCA applied. Reduced embeddings shape: (1173, 150)
# 2024-10-12 19:26:33,917 - INFO - UMAP applied in 2D, resulting in shape (1173, 2)
# 2024-10-12 19:26:34,014 - INFO - 2D UMAP plot saved at ./data/results/pca_2d

# %%
from src.services.embedding_visualizer_service import EmbeddingVisualizer

vis = EmbeddingVisualizer('./data/Natural-Questions-LLM-responses-400.csv', './data/results/pca_3d')
vis.load_data()
vis.process_embeddings_PCA(target_dim=200)
vis.apply_umap(n_components=3)
vis.plot_umap_3d()
# Out:
# 2024-10-12 19:26:57,847 - INFO - Data loaded with shape (391, 12)
# 2024-10-12 19:26:57,848 - INFO - Columns: Index(['uid', 'question', 'true_answer', 'phi3', 'llama3.1', 'gemma2',
#        'embedding_phi3', 'embedding_llama3.1', 'embedding_gemma2',
#        'true_answer_embedding_phi3', 'true_answer_embedding_llama3.1',
#        'true_answer_embedding_gemma2'],
#       dtype='object')
# 2024-10-12 19:27:11,729 - INFO - Label names set to {0: 'Llama3', 1: 'Gemma2', 2: 'Phi3'}
# 2024-10-12 19:27:11,730 - INFO - PCA applied. Reduced embeddings shape: (1173, 200)
# 2024-10-12 19:27:14,866 - INFO - UMAP applied in 3D, resulting in shape (1173, 3)
# 2024-10-12 19:27:15,006 - INFO - 3D UMAP plot saved at ./data/results/pca_3d

# %%
from src.services.embedding_visualizer_service import EmbeddingVisualizer

vis = EmbeddingVisualizer('./data/Natural-Questions-LLM-responses-400.csv', './data/results/pca_8d_in_2d')
vis.load_data()
vis.process_embeddings_PCA(target_dim=100)
vis.apply_umap(n_components=8)
vis.plot_umap_8d_in_2d()
# Out:
# 2024-10-12 19:27:19,423 - INFO - Data loaded with shape (391, 12)
# 2024-10-12 19:27:19,423 - INFO - Columns: Index(['uid', 'question', 'true_answer', 'phi3', 'llama3.1', 'gemma2',
#        'embedding_phi3', 'embedding_llama3.1', 'embedding_gemma2',
#        'true_answer_embedding_phi3', 'true_answer_embedding_llama3.1',
#        'true_answer_embedding_gemma2'],
#       dtype='object')
# 2024-10-12 19:27:29,801 - INFO - Label names set to {0: 'Llama3', 1: 'Gemma2', 2: 'Phi3'}
# 2024-10-12 19:27:29,819 - INFO - PCA applied. Reduced embeddings shape: (1173, 100)
# 2024-10-12 19:27:33,088 - INFO - UMAP applied in 8D, resulting in shape (1173, 8)
# 2024-10-12 19:27:33,374 - INFO - 8D UMAP pairwise plot saved at ./data/results/pca_8d_in_2d

# %%
from src.services.embedding_visualizer_service import EmbeddingVisualizer

vis = EmbeddingVisualizer('./data/Natural-Questions-LLM-responses-400.csv', './data/results/pca_16d_in_3d')
vis.load_data()
vis.process_embeddings_PCA(target_dim=100)
vis.apply_umap(n_components=16)
vis.plot_umap_16d_in_3d()
# Out:
# 2024-10-12 19:27:40,294 - INFO - Data loaded with shape (391, 12)
# 2024-10-12 19:27:40,294 - INFO - Columns: Index(['uid', 'question', 'true_answer', 'phi3', 'llama3.1', 'gemma2',
#        'embedding_phi3', 'embedding_llama3.1', 'embedding_gemma2',
#        'true_answer_embedding_phi3', 'true_answer_embedding_llama3.1',
#        'true_answer_embedding_gemma2'],
#       dtype='object')
# 2024-10-12 19:27:50,276 - INFO - Label names set to {0: 'Llama3', 1: 'Gemma2', 2: 'Phi3'}
# 2024-10-12 19:27:50,289 - INFO - PCA applied. Reduced embeddings shape: (1173, 100)
# 2024-10-12 19:27:53,745 - INFO - UMAP applied in 16D, resulting in shape (1173, 16)
# 2024-10-12 19:27:54,389 - INFO - 16D UMAP 3D projection plot saved at ./data/results/pca_16d_in_3d
